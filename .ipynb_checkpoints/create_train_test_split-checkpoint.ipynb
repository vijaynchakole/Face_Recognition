# %%
import os
import cv2
import random

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'C:\\Users\\hp\\Desktop\\Face_Recognition'

# %%
folder = os.listdir(current_dir+'/'+'dataset')

# %%
folder
# Out:
# ['jinping', 'kim_jong_un', 'modi', 'putin', 'trump']

# %%
# creating training data folder
os.mkdir(current_dir + '/'+ 'training')

# %%
# creating testing data folder
os.mkdir(current_dir + '/' + 'testing')

# %%
# creating prediction data folder
os.mkdir(current_dir + '/' + 'predictions')

# %%
def create_train_test_split(label_folder):
    
    print(label_folder)
    # creating label folder in training data folder
    os.mkdir('training/'+label_folder)
    # creating label folder in testing data folder
    os.mkdir('testing/'+label_folder)
    
    img_file_list = []
    img_file_list = os.listdir('dataset/'+ label_folder)
    #print(img_file_list)
    
    img_count = 0
    img_count = len(img_file_list)
    print(img_count)
    
    # taking 20% percentage of images into testing
    twenty_percentage = 0
    twenty_percentage = int((img_count/100)*20)
    print(twenty_percentage)

    
    test_data = []
    # taking random images from label folder without replacement
    test_data = random.sample(img_file_list, twenty_percentage)
    print(len(test_data))
    #print(test_data)
    
    
    
    for image_file in test_data:
        # reading image from label folder
        img = cv2.imread('dataset/'+label_folder+'/'+image_file)

        # writing image into testing data folder
        status = cv2.imwrite('testing/'+ label_folder + '/'+ image_file, img)

        print('test data status ' + str(status))

        # removing written image from img_file_list for future safe coding
        img_file_list.remove(image_file)

    
    # now taking random images (10%) from label folder without replcament
    ten_percentage = int(twenty_percentage / 2)
    print(ten_percentage)
    
    
    prediction_data = []
    prediction_data = random.sample(img_file_list, ten_percentage)
    
    #print(prediction_data)
    print(len(prediction_data))
    
    
    
    cnt = 0  
    for image_file in prediction_data :
        # reading image from label folder
        cnt+=1
        img = cv2.imread('dataset/'+label_folder+'/'+image_file)
        
        # generate random number
        num1 = random.randint(0,5000)
        num2 = random.randint(0,5000)
        # writing image into testing data folder
        status = cv2.imwrite('predictions/'+ str(num1)+'-'+str(num2) + image_file, img)
        
        print('prediction data status ' + str(status))
        
        # removing written image from img_file_list for future safe coding
        img_file_list.remove(image_file)
        
    print(cnt)
    
    print(len(img_file_list))
    
    
    cnt = 0
    while(len(img_file_list)!=0):
        
        for image_file in img_file_list :
            cnt+=1
            # reading image from label folder
            img = cv2.imread('dataset/'+label_folder+'/'+image_file)

            # writing image into testing data folder
            status = cv2.imwrite('training/'+ label_folder + '/'+ image_file, img)

            print('training data status ' + str(status))

            img_file_list.remove(image_file)

    print(cnt)

# %%
for label_folder in os.listdir('dataset'):
    print(label_folder)
    create_train_test_split(label_folder)
# Out:
# jinping
# jinping
# ['01001ce635.jpg', '102439ed0e.jpg', '159aa3ec77.jpg', '160d74cf5b.jpg', '16c5d3d555.jpg', '18bc53b652.jpg', '1aa46674a0.jpg', '22a9c1a9e4.jpg', '33be8648e2.jpg', '3f095d90c0.jpg', '400a6fb9f7.jpg', '4037c1ef14.jpg', '49d9f9e663.jpg', '5228c02bf7.jpg', '5335611849.jpg', '59be4f9b3b.jpg', '5a5555be3e.jpg', '5abc91232c.jpg', '5cff88c8b2.jpg', '5ecfa0b430.jpg', '6335ea1757.jpg', '635932c1fa.jpg', '6a60242050.jpg', '6fdd9e060f.jpg', '73a4b025b2.jpg', '850e67e912.jpg', '8ae1f4f70c.jpg', '90f21c77e3.jpg', '912e4bd9c8.jpg', '935b813b26.jpg', '93fa4c42df.jpg', '946d592ea1.jpg', '98da7cfbd7.jpg', '9e591980b0.jpg', 'aad15a0d9a.jpg', 'ad636e791f.jpg', 'adc37ddcc3.jpg', 'afe43eb658.jpg', 'b7e7f559f9.jpg', 'b82dee08a8.jpg', 'ba436ae6c3.jpg', 'bc39375dda.jpg', 'bc4048ad95.jpg', 'c27ea15bf4.jpg', 'c3ff70715f.jpg', 'd1a8522723.jpg', 'df90d552fc.jpg', 'e0c333d0d1.jpg', 'ea6b603ad1.jpg', 'ec0d9a6b07.jpg', 'f0320da80c.jpg', 'f0ae03db5c.jpg', 'f915ca766d.jpg', 'fa8347ac9f.jpg', 'faf2f7aaa6.jpg']
# 55
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# kim_jong_un
# kim_jong_un
# ['0085c84395.jpg', '029ce057c0.jpg', '0d0b6fe7a7.jpg', '0e6a51c076.jpg', '12ee5bfc14.jpg', '14f6db0371.jpg', '168ed37530.jpg', '1883020f1d.jpg', '192f4d7b86.jpg', '19391c5128.jpg', '2384136a75.jpg', '257b5d3f3d.jpg', '26f0b1dcec.jpg', '2d7eb79d07.jpg', '3d890a4e05.jpg', '3f0e905a59.jpg', '47da0ef3f9.jpg', '523110eb63.jpg', '65e19c067c.jpg', '66ffc9eb23.jpg', '6b36c8e235.jpg', '6f4ee35f1c.jpg', '73002f1549.jpg', '7397317b57.jpg', '77524fc908.jpg', '7abe970467.jpg', '8398cdf405.jpg', '85b5c4c226.jpg', '9050bcf748.jpg', '952ab7ff53.jpg', '996ee7ab75.jpg', '9c3d24a4be.jpg', '9e0d8fc280.jpg', 'acedd1bdd4.jpg', 'b225080214.jpg', 'b8686b4296.jpg', 'bb88baa8a7.jpg', 'c88b10bbe9.jpg', 'cb98d0a2a7.jpg', 'daf453b25c.jpg', 'e1daa2104b.jpg', 'f39f067a66.jpg', 'f66fb11eb0.jpg', 'f93cff2f8c.jpg', 'fa49b2af2e.jpg', 'ffc7421b78.jpg']
# 46
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# modi
# modi
# ['02d00df36c.jpg', '051df6da2f.jpg', '094f7ef32f.jpg', '0f29346254.jpg', '10d2443f56.jpg', '11ef3bc348.jpg', '133f434b4f.jpg', '13fcda4f15.jpg', '17c49bba8f.jpg', '17f77bc74f.jpg', '1a9967d865.jpg', '1c17ce92cd.jpg', '1c2da56c00.jpg', '233ee1acf8.jpg', '2a0ee789e9.jpg', '2d06b4afab.jpg', '2e12775d78.jpg', '31ca19701b.jpg', '3301e75da7.jpg', '3485919c89.jpg', '40aaf510a8.jpg', '44a984e887.jpg', '5caa875896.jpg', '6462a6deec.jpg', '6ebaf088b8.jpg', '753079374f.jpg', '7ea3d58759.jpg', '879b078d90.jpg', '8abfd91c2a.jpg', '8eef6098b9.jpg', '8fb6ea8f52.jpg', '902e802b06.jpg', '926cfc49b8.jpg', '92880b494b.jpg', '9959e5fd5e.jpg', '9c1cf347d8.jpg', 'a005f8b6b0.jpg', 'a2e38b9d91.jpg', 'a895dd3850.jpg', 'aa91ce7226.jpg', 'ab82c7d29c.jpg', 'add8f97bfd.jpg', 'b29ea0776a.jpg', 'b2b562fb10.jpg', 'b99e22efc8.jpg', 'bbaf639657.jpg', 'c48b6e6de8.jpg', 'c5c052846e.jpg', 'c668c14ad9.jpg', 'c8f03c2051.jpg', 'ca18ae4f48.jpg', 'ca4451279d.jpg', 'e441911b90.jpg', 'eacd238113.jpg', 'ef74c7aecf.jpg', 'f3d341f1c8.jpg', 'f44f19de5c.jpg', 'f940052071.jpg', 'fc134e32ad.jpg', 'fde494c143.jpg']
# 60
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# putin
# putin
# ['01c1a77b21.jpg', '02b0f084f7.jpg', '0343bda2d2.jpg', '05e27521be.jpg', '067f9d1f46.jpg', '075b772143.jpg', '077e3190d3.jpg', '07dff49d4e.jpg', '0f3cc787ee.jpg', '0f58f24a78.jpg', '12fc5d49a7.jpg', '1d61fba8b3.jpg', '1dd02e0c15.jpg', '24e6e25e4d.jpg', '26ca648cf3.jpg', '289673b094.jpg', '2d1d912fb3.jpg', '2dae2e957d.jpg', '360a9d90d0.jpg', '37f52f03bb.jpg', '38baa7307c.jpg', '3b83938c6b.jpg', '3bda9fbf02.jpg', '3e4e9c1286.jpg', '40bcdd0b76.jpg', '4491305e87.jpg', '5398e2a890.jpg', '643c8670cf.jpg', '65a568ffc5.jpg', '65ddd3c039.jpg', '672e7e383a.jpg', '67789550be.jpg', '6a42365786.jpg', '6d019c9a95.jpg', '6ee64c18a3.jpg', '75eabf1cd1.jpg', '7603b9a8f1.jpg', '76f9c1bcce.jpg', '7945586cf5.jpg', '7b5f183aac.jpg', '7bf90dd1e8.jpg', '7e79f2158b.jpg', '8525af2c97.jpg', '891d61b086.jpg', '8afabdb3c9.jpg', '8bb8028765.jpg', '8cac099ae6.jpg', '911b026fba.jpg', '92992e4363.jpg', '92c2102106.jpg', '985f2a0433.jpg', '9b0d6265da.jpg', '9c29dd2a8b.jpg', '9ea6f347d2.jpg', '9ed7afdae8.jpg', '9eedef1631.jpg', 'a60a62e02c.jpg', 'ac1f261f21.jpg', 'b03260ba3c.jpg', 'b07edcd65d.jpg', 'b3d7d47195.jpg', 'bc0008e4c5.jpg', 'bc8290a6b6.jpg', 'c036720745.jpg', 'c43f9a925f.jpg', 'c6dd056c28.jpg', 'ca985a662d.jpg', 'caa41fad09.jpg', 'ce45ef65dd.jpg', 'd7ce26eae7.jpg', 'ddcd7f42c7.jpg', 'df37faec51.jpg', 'dfd9f2d05e.jpg', 'e078e64bae.jpg', 'e1698b6b53.jpg', 'ebcdb2ab9f.jpg', 'f1f9627987.jpg', 'fbdd7aa1f9.jpg', 'fc8bb31814.jpg', 'ffc72d4eab.jpg']
# 80
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# trump
# trump
# ['008be3e5ef.jpg', '0269c8b4dc.jpg', '0b47398513.jpg', '0d829ab045.jpg', '0eb303d6f6.jpg', '134e71299e.jpg', '170c22a587.jpg', '18aed74e5c.jpg', '1a37a3366d.jpg', '277e4f95c9.jpg', '32ba0cd490.jpg', '35d3097b07.jpg', '363e18cabd.jpg', '43976fb050.jpg', '4aec2ffd54.jpg', '4b5785b000.jpg', '4cefc4eebf.jpg', '4dc19eb033.jpg', '50e28899c4.jpg', '5c5e77270a.jpg', '609e90f01f.jpg', '61f5732fa2.jpg', '704de72329.jpg', '796cb57e3a.jpg', '7aab592f33.jpg', '7d2c3fdc38.jpg', '7e3e11c09a.jpg', '8572efebfc.jpg', '89a81ab2d2.jpg', '8f7143ed13.jpg', '8f811c4bb6.jpg', '93af4c89db.jpg', '994377a9f0.jpg', '9e170be4b9.jpg', 'a595888c1b.jpg', 'a63a06eaa8.jpg', 'ab517ab5d2.jpg', 'b46eafc44e.jpg', 'b7a9526cef.jpg', 'b98cfa66f5.jpg', 'bebef3eaa8.jpg', 'bf1d5b75c9.jpg', 'c7086868a7.jpg', 'cb9aa11e67.jpg', 'cfe4bd501c.jpg', 'd08abf4c7a.jpg', 'd79d1de954.jpg', 'd837534ee1.jpg', 'd97742442c.jpg', 'dd0544a413.jpg', 'e00c6ac56d.jpg', 'e1c4ddc9c0.jpg', 'e25d63d0bf.jpg', 'e670d39c91.jpg', 'e765cb5ac0.jpg', 'e7d2da6da6.jpg', 'e9487ff292.jpg', 'eb8b2564d3.jpg', 'eef59662c7.jpg', 'ef0e6b178f.jpg', 'efc55fcd14.jpg', 'f2e6f9f21f.jpg', 'f8cf11bba8.jpg', 'fecb55c0b1.jpg', 'ff4d587929.jpg']
# 65
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
# training data status True
